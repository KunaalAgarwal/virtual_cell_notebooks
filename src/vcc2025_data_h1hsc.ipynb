# %% [markdown]
# Extraction of the H1 Human embryonic stem cell scRNA-seq dataset. 300k cells with 300 genes.
#
# https://github.com/ArcInstitute/arc-virtual-cell-atlas/blob/main/virtual-cell-challenge/README.md
#
# https://github.com/ArcInstitute/arc-virtual-cell-atlas/blob/main/virtual-cell-challenge/tutorial-py.ipynb

# %%
import io
import pandas as pd
import scanpy as sc
import gcsfs
# Out:
# /home/kunaal/personal_projects/virtual_cell/virtual_cell_notebooks/virtual_cell_env/lib/python3.10/site-packages/google/api_core/_python_version_support.py:254: FutureWarning: You are using a Python version (3.10.12) which Google will stop supporting in new releases of google.api_core once it reaches its end of life (2026-10-04). Please upgrade to the latest Python version, or at least Python 3.11, to continue receiving updates for google.api_core past that date.
#   warnings.warn(message, FutureWarning)
# /home/kunaal/personal_projects/virtual_cell/virtual_cell_notebooks/virtual_cell_env/lib/python3.10/site-packages/google/api_core/_python_version_support.py:254: FutureWarning: You are using a Python version (3.10.12) which Google will stop supporting in new releases of google.cloud._storage_v2 once it reaches its end of life (2026-10-04). Please upgrade to the latest Python version, or at least Python 3.11, to continue receiving updates for google.cloud._storage_v2 past that date.
#   warnings.warn(message, FutureWarning)
# /home/kunaal/personal_projects/virtual_cell/virtual_cell_notebooks/virtual_cell_env/lib/python3.10/site-packages/google/api_core/_python_version_support.py:254: FutureWarning: You are using a Python version (3.10.12) which Google will stop supporting in new releases of google.cloud.storage_control_v2 once it reaches its end of life (2026-10-04). Please upgrade to the latest Python version, or at least Python 3.11, to continue receiving updates for google.cloud.storage_control_v2 past that date.
#   warnings.warn(message, FutureWarning)

# %%
fs = gcsfs.GCSFileSystem()

# %%
vcc_base_path = "gs://arc-institute-virtual-cell-atlas/virtual-cell-challenge/2025/"
train_adata_path = vcc_base_path + "train/adata_Training.h5ad"
val_adata_path = vcc_base_path + "validation/adata_Validation.h5ad"

# %%
with fs.open(train_adata_path) as f:
    adata = sc.read_h5ad(f)
adata
# Out:
# Could not determine bucket type for bucket name arc-institute-virtual-cell-atlas: Your default credentials were not found. To set up Application Default Credentials, see https://cloud.google.com/docs/authentication/external/set-up-adc for more information., falling back to GCSFileSystem
# Could not determine bucket type for bucket name arc-institute-virtual-cell-atlas: Your default credentials were not found. To set up Application Default Credentials, see https://cloud.google.com/docs/authentication/external/set-up-adc for more information., falling back to GCSFileSystem
# Could not determine bucket type for bucket name arc-institute-virtual-cell-atlas: Your default credentials were not found. To set up Application Default Credentials, see https://cloud.google.com/docs/authentication/external/set-up-adc for more information., falling back to GCSFileSystem
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 2
#       1 with fs.open(train_adata_path) as f:
# ----> 2     adata = sc.read_h5ad(f)
#       3 adata
#
# File ~/personal_projects/virtual_cell/virtual_cell_notebooks/virtual_cell_env/lib/python3.10/site-packages/anndata/_io/h5ad.py:263, in read_h5ad(filename, backed, as_sparse, as_sparse_fmt, chunk_size)
#     260         return read_dataframe(elem)
#     261     return func(elem)
# --> 263 adata = read_dispatched(f, callback=callback)
#     265 # Backwards compat (should figure out which version)
#     266 if "raw.X" in f:
#
# File ~/personal_projects/virtual_cell/virtual_cell_notebooks/virtual_cell_env/lib/python3.10/site-packages/anndata/experimental/_dispatch_io.py:42, in read_dispatched(elem, callback)
#      38 from anndata._io.specs import _REGISTRY, Reader
#      40 reader = Reader(_REGISTRY, callback=callback)
# ---> 42 return reader.read_elem(elem)
#
# File ~/personal_projects/virtual_cell/virtual_cell_notebooks/virtual_cell_env/lib/python3.10/site-packages/anndata/_io/utils.py:215, in report_read_key_on_error.<locals>.func_wrapper(*args, **kwargs)
#     213     raise ValueError(msg)
#     214 try:
# --> 215     return func(*args, **kwargs)
#     216 except Exception as e:
#     217     path, key = _get_display_path(store).rsplit("/", 1)
#
# File ~/personal_projects/virtual_cell/virtual_cell_notebooks/virtual_cell_env/lib/python3.10/site-packages/anndata/_io/specs/registry.py:281, in Reader.read_elem(self, elem, modifiers)
#     279 if self.callback is None:
#     280     return read_func(elem)
# --> 281 return self.callback(read_func, elem.name, elem, iospec=iospec)
#
# File ~/personal_projects/virtual_cell/virtual_cell_notebooks/virtual_cell_env/lib/python3.10/site-packages/anndata/_io/h5ad.py:244, in read_h5ad.<locals>.callback(func, elem_name, elem, iospec)
#     241 def callback(func, elem_name: str, elem, iospec):
#     242     if iospec.encoding_type == "anndata" or elem_name.endswith("/"):
#     243         return AnnData(
# --> 244             **{
#     245                 # This is covering up backwards compat in the anndata initializer
#     246                 # In most cases we should be able to call `func(elen[k])` instead
#     247                 k: read_dispatched(elem[k], callback)
#     248                 for k in elem.keys()
#     249                 if not k.startswith("raw.")
#     250             }
#     251         )
#     252     elif elem_name.startswith("/raw."):
#     253         return None
#
# File ~/personal_projects/virtual_cell/virtual_cell_notebooks/virtual_cell_env/lib/python3.10/site-packages/anndata/_io/h5ad.py:247, in <dictcomp>(.0)
#     241 def callback(func, elem_name: str, elem, iospec):
#     242     if iospec.encoding_type == "anndata" or elem_name.endswith("/"):
#     243         return AnnData(
#     244             **{
#     245                 # This is covering up backwards compat in the anndata initializer
#     246                 # In most cases we should be able to call `func(elen[k])` instead
# --> 247                 k: read_dispatched(elem[k], callback)
#     248                 for k in elem.keys()
#     249                 if not k.startswith("raw.")
#     250             }
#     251         )
#     252     elif elem_name.startswith("/raw."):
#     253         return None
#
# File ~/personal_projects/virtual_cell/virtual_cell_notebooks/virtual_cell_env/lib/python3.10/site-packages/anndata/experimental/_dispatch_io.py:42, in read_dispatched(elem, callback)
#      38 from anndata._io.specs import _REGISTRY, Reader
#      40 reader = Reader(_REGISTRY, callback=callback)
# ---> 42 return reader.read_elem(elem)
#
# File ~/personal_projects/virtual_cell/virtual_cell_notebooks/virtual_cell_env/lib/python3.10/site-packages/anndata/_io/utils.py:215, in report_read_key_on_error.<locals>.func_wrapper(*args, **kwargs)
#     213     raise ValueError(msg)
#     214 try:
# --> 215     return func(*args, **kwargs)
#     216 except Exception as e:
#     217     path, key = _get_display_path(store).rsplit("/", 1)
#
# File ~/personal_projects/virtual_cell/virtual_cell_notebooks/virtual_cell_env/lib/python3.10/site-packages/anndata/_io/specs/registry.py:281, in Reader.read_elem(self, elem, modifiers)
#     279 if self.callback is None:
#     280     return read_func(elem)
# --> 281 return self.callback(read_func, elem.name, elem, iospec=iospec)
#
# File ~/personal_projects/virtual_cell/virtual_cell_notebooks/virtual_cell_env/lib/python3.10/site-packages/anndata/_io/h5ad.py:261, in read_h5ad.<locals>.callback(func, elem_name, elem, iospec)
#     258 elif elem_name in {"/obs", "/var"}:
#     259     # Backwards compat
#     260     return read_dataframe(elem)
# --> 261 return func(elem)
#
# File ~/personal_projects/virtual_cell/virtual_cell_notebooks/virtual_cell_env/lib/python3.10/site-packages/anndata/_io/specs/methods.py:806, in read_sparse(elem, _reader)
#     801 @_REGISTRY.register_read(H5Group, IOSpec("csc_matrix", "0.1.0"))
#     802 @_REGISTRY.register_read(H5Group, IOSpec("csr_matrix", "0.1.0"))
#     803 @_REGISTRY.register_read(ZarrGroup, IOSpec("csc_matrix", "0.1.0"))
#     804 @_REGISTRY.register_read(ZarrGroup, IOSpec("csr_matrix", "0.1.0"))
#     805 def read_sparse(elem: GroupStorageType, *, _reader: Reader) -> CSMatrix | CSArray:
# --> 806     return sparse_dataset(elem).to_memory()
#
# File ~/personal_projects/virtual_cell/virtual_cell_notebooks/virtual_cell_env/lib/python3.10/site-packages/anndata/_core/sparse_dataset.py:626, in BaseCompressedSparseDataset.to_memory(self)
#     622 format_class = get_memory_class(
#     623     self.format, use_sparray_in_io=settings.use_sparse_array_on_read
#     624 )
#     625 mtx = format_class(self.shape, dtype=self.dtype)
# --> 626 mtx.data = self._data[...]
#     627 mtx.indices = self._indices[...]
#     628 mtx.indptr = self._indptr
#
# File h5py/_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py/_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File ~/personal_projects/virtual_cell/virtual_cell_notebooks/virtual_cell_env/lib/python3.10/site-packages/h5py/_hl/dataset.py:872, in Dataset.__getitem__(self, args, new_dtype)
#     870 if self._fast_read_ok and (new_dtype is None):
#     871     try:
# --> 872         return self._fast_reader.read(args)
#     873     except TypeError:
#     874         pass  # Fall back to Python read pathway below
#
# File h5py/_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py/_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File h5py/_selector.pyx:393, in h5py._selector.Reader.read()
#
# File h5py/h5fd.pyx:159, in h5py.h5fd.H5FD_fileobj_read()
#
# File ~/personal_projects/virtual_cell/virtual_cell_notebooks/virtual_cell_env/lib/python3.10/site-packages/fsspec/spec.py:2196, in AbstractBufferedFile.readinto(self, b)
#    2191 """mirrors builtin file's readinto method
#    2192
#    2193 https://docs.python.org/3/library/io.html#io.RawIOBase.readinto
#    2194 """
#    2195 out = memoryview(b).cast("B")
# -> 2196 data = self.read(out.nbytes)
#    2197 out[: len(data)] = data
#    2198 return len(data)
#
# File ~/personal_projects/virtual_cell/virtual_cell_notebooks/virtual_cell_env/lib/python3.10/site-packages/fsspec/spec.py:2178, in AbstractBufferedFile.read(self, length)
#    2175 if length == 0:
#    2176     # don't even bother calling fetch
#    2177     return b""
# -> 2178 out = self.cache._fetch(self.loc, self.loc + length)
#    2180 logger.debug(
#    2181     "%s read: %i - %i %s",
#    2182     self,
#    (...)
#    2185     self.cache._log_stats(),
#    2186 )
#    2187 self.loc += len(out)
#
# File ~/personal_projects/virtual_cell/virtual_cell_notebooks/virtual_cell_env/lib/python3.10/site-packages/fsspec/caching.py:69, in BaseCache._fetch(self, start, stop)
#      67 if start >= self.size or start >= stop:
#      68     return b""
# ---> 69 return self.fetcher(start, stop)
#
# File ~/personal_projects/virtual_cell/virtual_cell_notebooks/virtual_cell_env/lib/python3.10/site-packages/gcsfs/core.py:2661, in GCSFile._fetch_range(self, start, end)
#    2659 try:
#    2660     if hasattr(self, "_prefetch_engine") and self._prefetch_engine:
# -> 2661         return self._prefetch_engine.fetch(start=start, end=end)
#    2662     return self.fs.cat_file(
#    2663         self.path,
#    2664         start=start,
#    (...)
#    2668         cache_source=self.cache_source,
#    2669     )
#    2670 except RuntimeError as e:
#
# File ~/personal_projects/virtual_cell/virtual_cell_notebooks/virtual_cell_env/lib/python3.10/site-packages/gcsfs/prefetcher.py:867, in BackgroundPrefetcher.fetch(self, start, end)
#     865 """Synchronous API wrapper delegating to `afetch`."""
#     866 # Delegates all boundaries, checking, and fetching to the async event loop perfectly
# --> 867 return fsspec.asyn.sync(self.loop, self.afetch, start, end)
#
# File ~/personal_projects/virtual_cell/virtual_cell_notebooks/virtual_cell_env/lib/python3.10/site-packages/fsspec/asyn.py:91, in sync(loop, func, timeout, *args, **kwargs)
#      88 asyncio.run_coroutine_threadsafe(_runner(event, coro, result, timeout), loop)
#      89 while True:
#      90     # this loops allows thread to get interrupted
# ---> 91     if event.wait(1):
#      92         break
#      93     if timeout is not None:
#
# File /usr/lib/python3.10/threading.py:607, in Event.wait(self, timeout)
#     605 signaled = self._flag
#     606 if not signaled:
# --> 607     signaled = self._cond.wait(timeout)
#     608 return signaled
#
# File /usr/lib/python3.10/threading.py:324, in Condition.wait(self, timeout)
#     322 else:
#     323     if timeout > 0:
# --> 324         gotit = waiter.acquire(True, timeout)
#     325     else:
#     326         gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %%
counts_path = vcc_base_path + "train/pert_counts_Training.csv"
counts = pd.read_csv(fs.open(counts_path))
counts.head()
# Out:
# Could not determine bucket type for bucket name arc-institute-virtual-cell-atlas: Your default credentials were not found. To set up Application Default Credentials, see https://cloud.google.com/docs/authentication/external/set-up-adc for more information., falling back to GCSFileSystem
# Could not determine bucket type for bucket name arc-institute-virtual-cell-atlas: Your default credentials were not found. To set up Application Default Credentials, see https://cloud.google.com/docs/authentication/external/set-up-adc for more information., falling back to GCSFileSystem
# Could not determine bucket type for bucket name arc-institute-virtual-cell-atlas: Your default credentials were not found. To set up Application Default Credentials, see https://cloud.google.com/docs/authentication/external/set-up-adc for more information., falling back to GCSFileSystem
#   target_gene  n_cells  median_umi_per_cell
# 0      TMSB4X     4760              53652.0
# 1        PRCP     4331              54594.0
# 2       TADA1     4035              52376.0
# 3        HIRA     3407              54068.0
# 4       IGF2R     3109              55754.0
